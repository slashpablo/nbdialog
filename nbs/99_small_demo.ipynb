# %% [markdown]
# # Small demo
# > Small test subject used to understand and test notebook internals
# - skip_exec: true

# %%
from nbdialog.core import *
from nbdialog.providers.azure import AzureProvider
from nbdialog.tools import search, browse
set_provider(AzureProvider())
set_tools([search.web_search, browse.browse])

# %%
# %%prompt
# write me hello world in python, like a pirate!
# Out:
# ```python
# print("Ahoy, world!")
# ```

# %%
def hello():
    print("Hello matey!")

hello()
# Out:
# Hello matey!

# %%
# %%prompt
# which is better?
# Out:
# Yours, for pirate flavor.
#
# - Mine is the classic minimal “hello world”
# - Yours is reusable and more piratey
#
# If you want both:
#
# ```python
# def hello():
#     print("Ahoy, world!")
#
# hello()
# ```

# %%
# %%prompt --force
# Give me top 5 news about bitcoin as of May 12 2026
# Out:
# Top 5 bitcoin news items I can identify for **May 12, 2026**:
#
# 1. **Bitcoin slips on geopolitical risk**
#    - Reports say BTC fell about **1% to ~$80.8K** as traders reacted to **rising Middle East tensions**, with broader risk assets weakening too.
#    - Source surfaced: CoinDesk
#
# 2. **Arthur Hayes predicts BTC rebound toward $126K**
#    - A CoinDesk piece reports Hayes saying bitcoin likely bottomed near **$60K** earlier in 2026 and could move back above **$90K** on the way to **$126K**.
#    - Source surfaced: CoinDesk
#
# 3. **Morgan Stanley’s bitcoin ETF reportedly draws strong early inflows**
#    - A May 12 digest cites reporting that **Morgan Stanley’s bitcoin ETF absorbed $194M in its first month** with **no daily net outflows**.
#    - Source surfaced via digest / The Block reference
#
# 4. **Bitcoin holds near key support around $80K–$81K**
#    - Market coverage on May 12 highlights BTC hovering just above an important support zone while macro pressure weighed on sentiment.
#    - Source surfaced: CoinDesk / market-price coverage
#
# 5. **Bitcoin price snapshot: about $80,860 on May 12**
#    - Multiple price/news pages list BTC near **$80.86K** that morning, reinforcing the day’s main theme: consolidation after recent strength.
#    - Source surfaced: Fortune / broader market pages
#
# A quick caveat: I’m pulling from live search snippets, so this is a **best-effort news roundup**, not a fully verified editorial ranking. If you want, I can do a stricter version with **linked sources and 1–2 sentence summaries from primary articles only**.
