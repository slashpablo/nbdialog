# %% [markdown]
# # Small demo
# > Small test subject used to understand and test notebook internals
# - skip_exec: true

# %%
from nbdialog.core import *
from nbdialog.providers.azure import AzureProvider
from nbdialog.tools import search, browse
set_provider(AzureProvider())
set_tools([search.web_search, browse.browse])

# %%
# %%prompt
# write me hello world in python, like a pirate!
# Out:
# ```python
# print("Ahoy, world!")
# ```

# %%
def hello():
    print("Hello matey!")

hello()
# Out:
# Hello matey!

# %%
# %%prompt
# which is better?
# Out:
# Yours, for pirate flavor.
#
# - Mine is the classic minimal “hello world”
# - Yours is reusable and more piratey
#
# If you want both:
#
# ```python
# def hello():
#     print("Ahoy, world!")
#
# hello()
# ```

# %%
# %%prompt --trace
# Give me top 5 news about bitcoin as of May 12 2026
# Out:
# <style>
# .nbd-trace { font-family: ui-monospace, SFMono-Regular, Menlo, monospace; font-size: 12px; margin: 0.5em 0; }
# .nbd-trace > summary { cursor: pointer; user-select: none; padding: 4px 8px; background: rgba(127,127,127,0.10); border-radius: 4px; }
# .nbd-trace .nbd-turn { padding: 6px 10px; border-left: 2px solid rgba(127,127,127,0.3); margin: 6px 0 6px 12px; }
# .nbd-trace .nbd-badge { display: inline-block; padding: 1px 6px; border-radius: 3px; font-size: 10px; font-weight: 600; margin-right: 6px; vertical-align: 1px; }
# .nbd-trace .nbd-badge-prompt { background: rgba(127,127,127,0.20); color: inherit; }
# .nbd-trace .nbd-badge-model  { background: rgba(64,128,255,0.18);  color: #4080ff; }
# .nbd-trace .nbd-badge-tool   { background: rgba(255,165,0,0.20);   color: #d67a00; }
# .nbd-trace .nbd-meta { color: rgba(127,127,127,0.85); font-size: 11px; }
# .nbd-trace pre { background: rgba(127,127,127,0.08); padding: 6px 8px; border-radius: 3px; white-space: pre-wrap; word-break: break-word; margin: 4px 0; font-size: 11px; }
# .nbd-trace details { margin: 4px 0; }
# .nbd-trace details > summary { cursor: pointer; user-select: none; }
# </style><details class="nbd-trace"><summary>trace · 3 model turns · 6 tool calls · 23.2s · 11,294 tokens</summary><div class="nbd-turn"><span class="nbd-badge nbd-badge-prompt">prompt</span><pre>Give me top 5 news about bitcoin as of May 12 2026
# </pre></div><div class="nbd-turn"><span class="nbd-badge nbd-badge-model">model</span><span class="nbd-meta">turn 1 · 2.69s · 709 tokens</span><details><summary>calls <code>web_search</code></summary><pre>{
#   &quot;query&quot;: &quot;Bitcoin news May 12 2026 top headlines&quot;,
#   &quot;k&quot;: 10
# }</pre></details></div><div class="nbd-turn"><span class="nbd-badge nbd-badge-tool">tool</span><span class="nbd-meta">web_search(query=&quot;Bitcoin news May 12 2026 top headlines&quot;, k=10) · 0.86s · 4,657 chars</span><details><summary>result</summary><pre>## Bitcoin News Digest May 12, 2026 - by Mike Richardson
# https://bitcoinnewsdigest.substack.com/p/bitcoin-news-digest-may-12-2026
# Morgan Stanley’s bitcoin ETF absorbs $194 million in first month with no net daily outflows, https://www.theblock.co/post/400650/morgan-stanleys-bitcoin-etf-absorbs-194-million-in-first-month-with-no-net-daily-outflows · Trump says he’ll suspend federal gas tax to help address high fuel prices due to Iran war, https://bronx.news12.com/2026/05/11/trump-says-hell-suspend-federal-gas-tax-to-help-address-high-fuel-prices-due-to-iran-war/5FtbPrLzLZ7fiUSkTX5wlN
#
# ## Bitcoin News Today: Latest BTC Price, Mining &amp; Market Headlines
# https://cryptoslate.com/news/bitcoin/
# The latest Bitcoin news today — live BTC price updates, mining developments, halving cycles, ETF flows, and institutional adoption headlines. CryptoSlate’s editorial team covers Bitcoin around the clock, from on-chain data and technical analysis to regulation and macro context, with breaking stories added throughout the day. ... Kagan’s warning links Iran’s Hormuz leverage to oil, rates, and a new Bitcoin macro risk. ... XRP products attracted fresh inflows, but the token’s next breakout attempt may depend on whether Bitcoin holds $80,000 through the next US inflation test.</pre></details></div><div class="nbd-turn"><span class="nbd-badge nbd-badge-model">model</span><span class="nbd-meta">turn 3 · 2.21s · 2,107 tokens</span><details><summary>calls <code>browse</code></summary><pre>{
#   &quot;url&quot;: &quot;https://bitcoinnewsdigest.substack.com/p/bitcoin-news-digest-may-12-2026&quot;,
#   &quot;max_chars&quot;: 12000
# }</pre></details><details><summary>calls <code>browse</code></summary><pre>{
#   &quot;url&quot;: &quot;https://www.theblock.co/&quot;,
#   &quot;max_chars&quot;: 12000
# }</pre></details><details><summary>calls <code>browse</code></summary><pre>{
#   &quot;url&quot;: &quot;https://www.coindesk.com/&quot;,
#   &quot;max_chars&quot;: 12000
# }</pre></details><details><summary>calls <code>browse</code></summary><pre>{
#   &quot;url&quot;: &quot;https://cryptoslate.com/news/bitcoin/&quot;,
#   &quot;max_chars&quot;: 12000
# }</pre></details><details><summary>calls <code>browse</code></summary><pre>{
#   &quot;url&quot;: &quot;https://fortune.com/article/price-of-bitcoin-05-12-2026/&quot;,
#   &quot;max_chars&quot;: 8000
# }</pre></details></div><div class="nbd-turn"><span class="nbd-badge nbd-badge-tool">tool</span><span class="nbd-meta">browse(url=&quot;https://bitcoinnewsdigest.substack.com/p/bitcoin-news-digest-may-12-2026&quot;, max_chars=12000) · 0.25s · 12,088
# Here are 5 notable Bitcoin-related news items for **May 12, 2026** based on current web reports:
#
# 1. **Bitcoin holds near $80K ahead of CPI and policy catalysts**
#    BTC traded around **$80.8K–$81.0K** on May 12, with markets watching U.S. inflation data, Washington crypto legislation, and geopolitical risk tied to Iran.
#    Source: CryptoSlate, Fortune
#
# 2. **Morgan Stanley’s spot Bitcoin ETF posts first month with zero outflows**
#    Morgan Stanley’s **MSBT** reportedly completed its first trading month without a single day of net outflows, while U.S. spot Bitcoin ETFs extended an inflow streak.
#    Source: CryptoSlate, Bitcoin News Digest
#
# 3. **A long-dormant Bitcoin whale moved roughly $40 million in BTC**
#    CoinDesk highlighted that a wallet inactive since **2013** became active again, moving tens of millions in bitcoin on-chain.
#    Source: CoinDesk
#
# 4. **Bitcoin briefly dipped below $80,000, but derivatives traders bet on recovery**
#    Reports said BTC slipped under $80K intraday, while options positioning suggested traders expected the weakness to be temporary rather than the start of a deeper selloff.
#    Source: CryptoSlate
#
# 5. **Bitcoin miners face pressure as they pivot toward AI infrastructure**
#    Public miners including **MARA** and **CleanSpark** reported large losses, with some selling bitcoin and reallocating capital toward AI/data-center expansion.
#    Source: Bitcoin News Digest
#
# **Price snapshot for May 12, 2026:**
# - Fortune reported **1 BTC = $80,860.97** at 9:15 a.m. ET.
#
# If you want, I can turn this into a **table with links** or give a **market-only summary** instead.
