# %% [markdown]
# # Small demo
# > Small test subject used to understand and test notebook internals
# - skip_exec: true

# %%
from nbdialog.core import *
from nbdialog.providers.azure import AzureProvider
set_provider(AzureProvider())

# %%
# %%prompt
# write me hello world in python, like a pirate!
# Out:
# ```python
# print("Ahoy, world!")
# ```

# %%
def hello():
    print("Hello matey!")

hello()
# Out:
# Hello matey!

# %%
# %%prompt
# which is better?
# Out:
# Yours, for pirate flavor.
#
# - Mine is the classic minimal “hello world”
# - Yours is reusable and more piratey
#
# If you want both:
#
# ```python
# def hello():
#     print("Ahoy, world!")
#
# hello()
# ```
