# %% [markdown]
# # Small demo
#
# Small test subject used to understand and test notebook internals

# %%
from nbdialog.core import *

# %%
# %%prompt
# write me hello world in python, like a pirate!
# Out:
# ```python
# print("Ahoy, world!")
# ```

# %%
def hello():
    print("Hello user!")

hello()
# Out:
# Hello user!

# %%
# %%prompt
# which is better?
# Out:
# Yours is better for actual code.
#
# The pirate version is better only as flavor, for example:
#
# ```python
# print("Ahoy, world!")
# ```
#
# But if the goal is a normal greeting function, your version is clearer:
#
# ```python
# def hello(): print("Hello user!")
# ```
#
# So: pirate version for style, yours for usefulness.
